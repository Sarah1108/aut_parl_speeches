# %% [markdown]
# ### ParlSpeech V2 data set
#
# The data set used in this thesis is the ParlSpeech V2 data set, containing speeches of 9 European parliaments, including the Austrian Nationalrat. The Austrian data was web scraped on the 26.11.2019 and includes speeches from January 1996 until December 2018. As the project worked with R, the data set is saved as an .rds file.
#
# [https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/L4OAKN]

# %%
#load libraries
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
import pandas as pd

import pickle as pkl
import regex as re
import matplotlib.pyplot as plt

# %%
# creating requirment file for used libraries
#!pip freeze > requirements.txt

# %% [markdown]
# [https://www.geeksforgeeks.org/how-to-create-requirements-txt-file-in-python/]
#
# [https://www.geeksforgeeks.org/using-jupyter-notebook-in-virtual-environment/]
#
#
# check& set up virtual enviroment

# %% [markdown]
# rpy2 library to read the rds file
# that was downloaded here:
# [https://rpy2.github.io/]

# %%
readRDS = robjects.r['readRDS']
df = readRDS('data\Corp_Nationalrat_V2.rds')
df = pandas2ri.rpy2py_dataframe(df)

# %%
'Explore data structure'
#print(df.head().to_markdown())
#df.shape
#print(df['text'][4])
#print(df['speaker'].unique())

# %%
#speaker_list= df['speaker'].unique()
#pattern= r'(\w+ \w+$)'
#df['speaker'] = df['speaker'].str.extract(pattern)

# %%
#check number of speakers, clean from Titles, other names by only taking the last two words of the name.
#cleaned_speaker_list= df['speaker'].unique()
#print(len(cleaned_speaker_list))
#print(len(speaker_list))

# %%
#replacing party names, as Jetzt - Liste PILZ, JETZT and PILZ are all one party
df['party']= df['party'].replace(to_replace='Jetzt – Liste PILZ', value='PILZ', regex=True)
df['party']= df['party'].replace(to_replace='JETZT', value='PILZ', regex=True)
#df['party'].unique()

# %% [markdown]
# #### thoughts on data storge
#
# [https://medium.com/@reza.shokrzad/pickle-json-or-parquet-unraveling-the-best-data-format-for-speedy-ml-solutions-10c3f7bf4d0c]
# Reading about the different kinds to store data, loading RFS Files just takes very long. I would like to shorten the process so I want to save the data after preprocessing it. Maybe Pickle is the best or tensor?
#
# Will have to read more.Definitely not JSON.
# [https://www.jumpingrivers.com/blog/arrow-rds-parquet-comparison/]
# Might have to look at parquet
#
# Most probably Pickle.

# %% [markdown]
# Datensatz hat folgende Spalten: <br>
# date <br>
# agenda<br>
# speechnumber<br>
# speaker<br>
# party<br>
# party.facts.id<br>
# chair<br>
# term<br>
# text<br>
# parliament<br>
# iso3country<br>

# %% [markdown]
# ##### Notes on data exploration
#
# We want to get to know the data set a bit better: <br>
#
# * How many speeches are there?
# * How long are they?
# * How long are they for each party?
# * How many speeches does each party have?
# * How many mps does each party have?
# * How much do single MPs speak?/How much do they speak individually compared to MPs of other parties?
# * Which agendas do they speak most about? <p/>
#
# * How many speeches are there for each legislation period?
# * Also all the other questions for each period.<p/>
#
# * How many MPs changed party?
# * How many MPs where not party affiliated anymore? <p/>
#
# * How long are government members speeches compared to MPs speeches?

# %%
#visualise parties/speech distribution
#df['party'].value_counts().plot(kind='bar',color=['grey','red','black','blue','green','orange','yellow','pink','grey','brown','black'])
df['party'].value_counts().plot(kind='bar',color=all_party_colors)
plt.title('Overall distribution of speeches in  ParlV2 data set')
print(df['party'].value_counts())
plt.show()
# Out:
# NA_character_    109707
# SPÖ               24747
# ÖVP               24063
# FPÖ               17308
# Grüne             12455
# BZÖ                4170
# LIF                1942
# NEOS               1866
# independent        1555
# STRONACH           1322
# PILZ                346
# Name: party, dtype: int64

# %%
all_party_colors= ['#ff0000','#000000','#0066ff','#92d050','#ee7f00','#fecd00','#e84188','#a9a9a9','#ffff40','#efebdc']

# %% [markdown]
# #### Comments on the distribution of the parties
#
# Most speeches are held by NA, in this case that means, that the speakes where not talking in their role as an MP but rather as part of the government.
#
# We can have a closer look at the speakers without party to find out if they are just persons that have been MPs before or other, non assosiated persons.
#
# As this is meant to train a text classification for party affiiliation, the speakers that can be affiliated with a party will be added to the party they where a member of, even if they were originally not tagged with that party in the data.
#
# How many speeches are held by the Präsident of the parliament?

# %%
#check how many speeches are held by the president of parliament
search = "präsident"
df['count_president']= df["speaker"].str.count(search, re.I)
print(df['count_president'].sum())

search_2 = "bundesminister"
df['count_minister']= df["speaker"].str.count(search_2, re.I)
print(df['count_minister'].sum())

search_3 = "schriftführer"
df['count_scribe'] = df["speaker"].str.count(search_3, re.I)
print(df['count_scribe'].sum())

print(df['count_scribe'].sum()+ df['count_president'].sum())
# Out:
# 109555
# 9624
# 152
# 109707

# %% [markdown]
# Looking at the speeches held by the ministers of parliament and the scribes, those are the speeches that have no party affiliation.
#
# We can have a closer look at those speeches maybe at another point, for now, we want to filter those speeches out of our data.

# %%
#filter out speeches by president of parliament and scribes
df = df[df['count_president']<1]
df = df[df['count_scribe']<1]
# number of actual speeches to be used
print(df.shape)
# Out:
# (89774, 14)

# %%
#visualise parties/speech distribution
df['party'].value_counts().plot(kind='bar',color=all_party_colors)
#print(df['party'].value_counts())
plt.show()

# %%
speaker_list= df['speaker'].unique()
pattern= r'(\w+ \w+$|\w+ \w+-\w+$|\w+ \w. \w+$)'
#first and last name OR first and combined last name - late edition because there where Nan Values!
df['speaker_new'] = df['speaker'].str.extract(pattern)

# %%
sittings=df['date'].unique()
len(sittings)
# Out:
# 600

# %%
agenda= df['agenda'].unique()
len(agenda)
# Out:
# 4852

# %%
df= df.rename(columns={'speaker':'speaker_old', 'speaker_new':'speaker'})

# %%
def assign_gov(date):
    if date >= pd.Timestamp('1996-01-15') and date < pd.Timestamp('1999-10-29'):
        return 0
    elif date >= pd.Timestamp('1999-10-29') and date < pd.Timestamp('2002-12-20'):
        return 1
    elif date >= pd.Timestamp('2002-12-20') and date < pd.Timestamp('2006-10-30'):
        return 2
    elif date >= pd.Timestamp('2006-10-30') and date < pd.Timestamp('2008-10-28'):
        return 3 
    elif date >= pd.Timestamp('2008-10-28') and date < pd.Timestamp('2013-10-29'):
        return 4
    elif date >= pd.Timestamp('2013-10-29') and date < pd.Timestamp('2017-11-08'):
        return 5 
    elif date >= pd.Timestamp('2017-11-08') and date < pd.Timestamp('2019-10-22'):
        return 6
    else:
        return 7

# %%
df['date_format']= pd.to_datetime(df['date'])

# %%
df['gov'] = df['date_format'].map(assign_gov)

# %%
for i in range(0,7):
    temp_df = df[df['gov']==i]
    sittings=temp_df['date'].unique()
    print(i)
    print(len(sittings))
    print(temp_df['party'].unique())
# Out:
# 0
# 112
# ['SPÖ' 'ÖVP' 'FPÖ' 'LIF' 'Grüne' 'independent']
# 1
# 77
# ['SPÖ' 'FPÖ' 'ÖVP' 'Grüne']
# 2
# 105
# ['SPÖ' 'FPÖ' 'ÖVP' 'Grüne' 'independent' 'LIF' 'BZÖ']
# 3
# 42
# ['SPÖ' 'ÖVP' 'Grüne' 'FPÖ' 'BZÖ' 'independent']
# 4
# 131
# ['SPÖ' 'ÖVP' 'FPÖ' 'BZÖ' 'Grüne' 'independent' 'STRONACH']
# 5
# 103
# ['SPÖ' 'FPÖ' 'Grüne' 'STRONACH' 'NEOS' 'ÖVP' 'LIF' 'independent']
# 6
# 30
# ['ÖVP' 'SPÖ' 'FPÖ' 'NEOS' 'PILZ' 'independent']

# %%
#df.to_excel('data/check_speakers.xlsx')
# Out:
# ['Heidrun Silhavy' 'Herbert Haupt' 'Walter Tancsits' 'Doris Bures'
#  'Maximilian Walch' 'Eva Glawischnig-Piesczek' 'Ridi Steibl'
#  'Rudolf Nürnberger' 'Sigisbert Dolinschek' 'Brigid Weinzinger'
#  'Josef Cap' 'der Bellen' 'Wilhelm Molterer' 'Herbert Scheibner'
#  'Wolfgang Schüssel' 'Alfred Gusenbauer' 'Friedrich Verzetnitsch'
#  'Karl Öllinger' 'Magda Bleckmann' 'Reinhold Mitterlehner'
#  'Michaela Sburny' 'Barbara Prammer' 'Karl Donabauer' 'Sabine Mandak'
#  'Christoph Matznetter' 'Elisabeth Scheucher-Pichler' 'Uwe Scheuch'
#  'Andrea Kuntzl' 'Reinhold Lopatka' 'Josef Broukal' 'Dieter Brosz'
#  'Klaus Wittauer' 'Karin Hakl' 'Theresia Haidlmayr' 'Helene Partik-Pablé'
#  'Karl Dobnigg' 'Karlheinz Kopf' 'Werner Kogler' 'Peter Pilz'
#  'Josef Trinkl' 'Gabriela Moser' 'Jakob Auer' 'Günter Stummvoll'
#  'Michael Spindelegger' 'Renate Csörgits' 'Elke Achleitner' 'Walter Posch'
#  'Christine Marek' 'Marianne Hagenhofer' 'Detlev Neudeck' 'Franz Riepl'
#  'Gabriele Heinisch-Hosek' 'Elmar Lichtenegger' 'Melitta Trunk'
#  'August Wöginger' 'Dietmar Keck' 'Maximilian Hofmann' 'Christine Lapp'
#  'Norbert Sieber' 'Walter Schopf' 'Anna Franz' 'Bettina Stadlbauer'
#  'Konrad Steindl' 'Erwin Spindelberger' 'Johann Rädler' 'Anita Fleckl'
#  'Gertrude Brinek' 'Rosemarie Schönpass' 'Mares Rossmann' 'Günther Hütl'
#  'Christoph Kainz' 'Josef Winkler' 'Eduard Mainoni' 'Ulrike Lunacek'
#  'Carina Felzmann' 'Josef Bucher' 'Günther Kräuter' 'Walter Murauer'
#  'Anton Gaál' 'Fritz Grillitsch' 'Heinz Grasser' 'Evelin Lichtenberger'
#  'Peter Schieder' 'Johann Kurzbauer' 'Caspar Einem' 'Wolfgang Pirklhuber'
#  'Edeltraud Lentsch' 'Otto Pendl' 'Erwin Rasinger'
#  'Heidemarie Rest-Hinterseer' 'Werner Amon' 'Eugen Bösch'
#  'Günther Platter' 'Anton Wattaul' 'Karl Freund' 'Kurt Grünewald'
#  'Barbara Rosenkranz' 'Erwin Niederwieser' 'Cordula Frieser'
#  'Terezija Stoisits' 'Astrid Stadler' 'Heidrun Walther' 'Christian Faul'
#  'Kurt Gartlehner' 'Hans Moser' 'Hermann Schultes' 'Kurt Gaßner'
#  'Barbara Riener' 'Heinz Gradwohl' 'Alfred Brader' 'Dietmar Hoscher'
#  'Michael Ikrath' 'Franz Glaser' 'Hannes Bauer' 'Jan Krainer'
#  'Peter Haubner' 'Rainer Wimmer' 'Herta Mikesch' 'Kurt Eder'
#  'Peter Marizzi' 'Werner Kummerer' 'Katharina Pfeffer' 'Rudolf Parnigoni'
#  'Stefan Prähauser' 'Hermann Krist' 'Anton Heinzl' 'Petra Bayr'
#  'Martin Bartenstein' 'Matthias Ellmauer' 'Maria Rauch-Kallat'
#  'Georg Keuschnigg' 'Erika Scharer' 'Roderich Regler' 'Helga Machne'
#  'Elisabeth Grossmann' 'Norbert Kapeller' 'Georg Oberhaidinger'
#  'Ulrike Königsberger-Ludwig' 'Susanne Wegscheider' 'Gerhard Steier'
#  'Christian Puswald' 'Michael Praßl' 'Gabriele Binder-Maier'
#  'Gabriele Tamandl' 'Fritz Neugebauer' 'Gisela Wurm' 'Martin Preineder'
#  'Johannes Jarolim' 'Ruth Becher' 'Johann Ledolter' 'Silvia Fuhrmann'
#  'Christine Muttonen' 'Manfred Lackner' 'Beate Schasching' 'Ulrike Sima'
#  'Erwin Kaipel' 'Gerhard Reheis' 'Robert Rada' 'Peter Wittmann'
#  'Ulrike Baumgartner-Gabitzer' 'Andrea Wolfmayr' 'Theresia Fekter'
#  'Hans Langreiter' 'Johannes Zweytick' 'Werner Fasslabend'
#  'Joseph Huainigg' 'Nikolaus Prinz' 'Notburga Schiefermair'
#  'Maria Grander' 'Johann Maier' 'Ingrid Turkovic-Wendl' 'Anna Höllerer'
#  'Hannes Missethon' 'Dieter Böhmdorfer' 'Heribert Donnerbauer'
#  'Günter Kößl' 'Jochen Pack' 'Xaver Böhm' 'Alfred Schöls'
#  'Johannes Schweisgut' 'Ferdinand Maier' 'Erwin Hornek' 'Josef Pröll'
#  'Hermann Gahr' 'Hubert Auer' 'Franz Eßl' 'Wolfgang Großruck'
#  'Ernst Strasser' 'Werner Miedl' 'Benita Ferrero-Waldner' 'Hubert Gorbach'
#  'Elisabeth Gehrer' 'Andreas Khol' 'Peter Sonnberger' 'Heinz Fischer'
#  'Thomas Prinzhorn' 'Norbert Darabos' 'Johann Moser' 'Anton Doppler'
#  'Vincenz Liechtenstein' 'Karin Miklautsch' 'Markus Fauland'
#  'Wolfgang Zinggl' 'Elisabeth Hlavac' 'Ursula Plassnik' 'Richard Leutner'
#  'Liese Prokop' 'Ursula Haubner' 'Marialuise Mittermüller'
#  'Karin Gastinger' 'Heinz Dernoscheg' 'Wolfgang Katzian'
#  'Christian Strache' 'Peter Westenthaler' 'Ewald Stadler'
#  'Peter Fichtenbauer' 'Harald Vilimsky' 'Herbert Kickl' 'Martin Graf'
#  'Gertrude Aubauer' 'Veit Schalle' 'Werner Neubauer' 'Norbert Hofer'
#  'Gernot Darmann' 'Bruno Rossmann' 'Gerhard Kurzmann' 'Hubert Kuzdas'
#  'Sylvia Prettenthaler' 'Lutz Weinzinger' 'Franz Kirchgatterer'
#  'Birgit Schatz' 'Robert Aspöck' 'Karlheinz Klement' 'Barbara Zwerschitz'
#  'Gerald Hauser' 'Dagmar Belakowitsch-Jenewein' 'Wilhelm Haberzettl'
#  'Beatrix Karl' 'Andrea Eder-Gitschthaler' 'Bernhard Themessl'
#  'Elmar Mayer' 'Josef Muchitsch' 'Peter Stauber' 'Sabine Oberhauser'
#  'Bettina Hradecsni' 'Wolfgang Zanger' 'Manfred Haimbuchner'
#  'Ruperta Lichtenecker' 'Franz Hörl' 'Erwin Buchinger' 'Werner Faymann'
#  'Maria Berger' 'Andrea Kdolsky' 'Claudia Schmied' 'Leopold Mayerhofer'
#  'Alexander Zach' 'Thomas Einwallner' 'Gabriel Obernosterer'
#  'Irina Fürntrath-Moretti' 'Andreas Schieder' 'Laura Rudas' 'Franz Morak'
#  'Hannes Fazekas' 'Alois Gradauer' 'Sebastian Eder' 'Helmut Kukacka'
#  'Sylvia Rinner' 'Sonja Ablinger' 'Christian Füller' 'Johann Höfinger'
#  'Dorothea Schittenhelm' 'Johannes Hahn' 'Peter Eisenschenk'
#  'Gerhard Köfer' 'Georg Schelling' 'Rosa Lohfeyer' 'Michael Ehmann'
#  'Albert Steinhauser' 'Christian Hursky' 'Claudia Durchschlag'
#  'Angela Lueger' 'Gertraud Knoll' 'Peter Kostelka' 'Jörg Haider'
#  'Volker Kier' 'Johannes Voggenhuber' 'Harald Ofner' 'Peter Haselsteiner'
#  'Andreas Wabl' 'Monika Langthaler' 'Franz Hums' 'Johannes Ditz'
#  'Josef Höchtl' 'Helmut Peter' 'Fritz Verzetnitsch' 'Franz Vranitzky'
#  'Helmut Haigermoser' 'Eleonora Hostasch' 'Leopold Maderthaner'
#  'Gilbert Trattner' 'Kurt Heindl' 'Georg Schwarzenberger'
#  'Günter Puttinger' 'Anton Blünegger' 'Peter Rosenstingl'
#  'Hermann Böhacker' 'Ewald Nowotny' 'Ilse Mertel'
#  'Friedhelm Frischenschlager' 'Maria Fekter' 'Hans Schöll' 'Heide Schmidt'
#  'Michael Krüger' 'Reinhard Firlinger' 'Alois Mock' 'Rosemarie Bauer'
#  'Madeleine Petrovic' 'Willi Fuhrmann' 'Dieter Antoni' 'Paul Kiss'
#  'Franz Stampler' 'Viktor Klima' 'Gottfried Feurstein' 'Dieter Lukesch'
#  'Emmerich Schwemlein' 'Franz Lafer' 'Josef Mühlbachler' 'Edith Haller'
#  'Erhard Koppler' 'Nikolaus Michalek' 'Walter Schwimmer'
#  'Thomas Barmüller' 'Anna Huber' 'Liane Höbinger-Lehrer' 'Josef Schrefel'
#  'Klara Motter' 'Rudolf Scholten' 'Susanne Preisinger' 'Karl Maitz'
#  'Helmut Moser' 'Gerald Tychtl' 'Leopold Schöggl' 'Rudolf Anschober'
#  'Otmar Brix' 'Elisabeth Aumayr' 'Elfriede Madl' 'Peter Keppelmüller'
#  'Helmut Dietachmayr' 'Robert Sigl' 'Kurt Wallner' 'Stefan Salzl'
#  'Inge Jäger' 'Edeltraud Gatterer' 'Anton Leikam' 'Mathias Reichhold'
#  'Holger Bauer' 'Udo Grollitsch' 'Franz Steindl' 'Annemarie Reitsamer'
#  'Maria Schaffenrath' 'Brigitte Ederer' 'Rudolf Schwarzböck'
#  'Doris Kammerlander' 'Brigitte Povysil' 'Christa Krammer'
#  'Johann Stippel' 'Hermann Kröll' 'Josef Edler' 'Günter Kiermaier'
#  'Richard Kaiser' 'Winfried Seidinger' 'Walter Meischberger' 'Josef Trenk'
#  'Arnold Grabner' 'Robert Wenitsch' 'Herbert Kaufmann' 'Georg Wurmitzer'
#  'Ludmilla Parfuss' 'Alois Pumberger' 'Brigitte Tegischer'
#  'Johann Schuster' 'Katharina Horngacher' 'Gerfried Müller' 'Ernst Fink'
#  'Kurt Ruthofer' 'Hermann Mentil' 'Franz Koller' 'Sonja Moser'
#  'Franz Kampichler' 'Hannelore Buder' 'Irmtraut Karlsson'
#  'Robert Elmecker' 'Matthias Achs' 'Karl Schweitzer' 'Walter Guggenberger'
#  'Josef Meisinger' 'Sophie Bauer' 'Elisabeth Pittermann' 'Helga Konrad'
#  'Willi Sauer' 'Brunhilde Fuchs' 'Heidemaria Onodi' 'Verena Dunst'
#  'Günther Leiner' 'Wolfgang Jung' 'Franz Linser' 'Wolfgang Riedler'
#  'Willi Brauneder' 'Ute Apfelbeck' 'Hannes Farnleitner' 'Franz Löschnak'
#  'Friedrich König' 'Martina Gredler' 'Wolfgang Nußbaumer'
#  'Erich L. Schreiner' 'Rudolf Edlinger' 'Reinhart Gaugg' 'Karl Schlögl'
#  'Susanne Rieß' 'Karl Smolle' 'Anton Marolt' 'Anneliese Klein'
#  'Harald Fischl' 'Wilfried Tilg' 'Dieter Teller' 'Karin Praxmarer'
#  'Hans Sevignani' 'Dietrich Teller' 'Susanne Riess-Passer'
#  'Gerhard Fallent' 'Herbert L. Graf' 'Christof Zernatto'
#  'Gerhart Bruckmann' 'Gerhard Bauer' 'Ernest Windholz' 'Hans Müller'
#  'Martina Pecher' 'Beate Hartinger' 'Reinhold Lexer'
#  'Norbert Staffaneller' 'Rüdiger Schender' 'Brunhilde Plank'
#  'Elisabeth Sickl' 'Theresia Zierler' 'Michael Schmid' 'Wilhelm Weinmeier'
#  'Patrick Ortlieb' 'Jakob Pistotnig' 'Roland Zellot' 'Franz Hornegger'
#  'Hermann Reindl' 'Johanna Mikl-Leitner' 'Sylvia Papházy' 'Robert Egghart'
#  'Maria Kubitschek' 'Anton Knerzl' 'Andreas Sodian' 'Ilse Burket'
#  'Bernd Brugger' 'Johann Loos' 'Jutta Wochesländer' 'Elisabeth Achatz'
#  'Monika Forstinger' 'Gerhard Hetzl' 'Kurt Scheuch' 'Evelyn Freigaßner'
#  'Josef Horn' 'Harald Trettenbrein' 'Josef Blasisker' 'Gerhard Abraham'
#  'Konstanze Röhrs' 'Bernhard Vock' 'Hannes Weninger' 'Hedwig Wechner'
#  'Hartmann Lautenschlager' 'Alfred Finz' 'Johann Hell' 'Kurt Nekula'
#  'Christoph Hagen' 'Robert Lugar' 'Roman Haider' 'Rudolf Hundstorfer'
#  'Stefan Petzner' 'Alev Korun' 'Heidemarie Unterreiner' 'Harald Walser'
#  'Johannes Hübner' 'Carmen Gartelgruber' 'Judith Schwentner'
#  'Rainer Widmann' 'Alois Stöger' 'Wolfgang Spadiut' 'Nikolaus Berlakovich'
#  'Harald Jannach' 'Maximilian Linder' 'Christiane Brunner'
#  'Martina Schenk' 'Tanja Windbüchler-Souschill' 'Harald Stefan'
#  'Gerald Grosz' 'Andreas Karlsböck' 'Daniela Musiol' 'Kurt List'
#  'Josef Jury' 'Gerhard Deimek' 'Gerhard Huber' 'Christian Höbart'
#  'Stefan Markowitz' 'Mario Kunasek' 'Oswald Klikovits'
#  'Werner Königshofer' 'Werner Herbert' 'Josef Auer' 'Walter Rosenkranz'
#  'Edith Mühlberghuber' 'Anneliese Kitzmüller' 'Rupert Doppler'
#  'Christian Lausch' 'Susanne Winter' 'Josef Lettenbichler' 'Erich Tadler'
#  'Claudia Bandion-Ortner' 'Andrea Gessl-Ranftl' 'Rudolf Plessl'
#  'Johann Singer' 'Maria Steibl' 'Bernd Schönegger'
#  'Katharina Cortolezis-Schlager' 'Ewald Sacher' 'Peter Mayer'
#  'Hermann Lipitsch' 'Johann Hechtl' 'Johannes Schmuckenschlager'
#  'Martin Strutz' 'Elisabeth Hakel' 'Helene Jarmer'
#  'Sonja Steßl-Mühlbacher' 'Peter Hackl' 'Erwin Preiner'
#  'Michael Schickhofer' 'Elmar Podgorschek' 'Josef A. Riemer'
#  'Michael Hammer' 'Karlheinz Töchterle' 'Rudolf Buchmayr'
#  'Wolfgang Gerstl' 'Mathias Venier' 'Elisabeth Kaufmann-Bruckberger'
#  'Franz Windisch' 'Maria Himmelbauer' 'Gerald Klug' 'Irene Szep'
#  'Silvia Grünberger' 'Jörg Jenewein' 'Kathrin Nachbaur' 'Matthias Strolz'
#  'Frank Stronach' 'Rosa Mlinar' 'Karin Greiner' 'Katharina Kucharowits'
#  'Julian Schmid' 'Leopold Steinbichler' 'Gerald Loacker' 'Georg Vetter'
#  'Nikolaus Alm' 'Christoph Vavrik' 'Marcus Franz' 'Michael Pock'
#  'Nikolaus Scherak' 'Beate Meinl-Reisinger' 'Rainer Hable'
#  'Waltraud Dietrich' 'Andreas Zakostelsky' 'Ulrike Weigerstorfer'
#  'Brigitte Jank' 'Hubert Fuchs' 'Angelika Winzig' 'Sigrid Maurer'
#  'Georg Willi' 'Andrä Rupprechter' 'Asdin El Habbassi'
#  'Wolfgang Brandstetter' 'Eva Mückstein' 'Berivan Aslan' 'Matthias Köchl'
#  'Petra Steger' 'Michaela Steinacker' 'Maximilian Unterrainer'
#  'Rouven Ertlschweiger' 'Philip Kucher' 'Wolfgang Knes' 'Georg Strasser'
#  'Cornelia Ecker' 'Axel Kassegger' 'Werner Groiß' 'Martina Diesner-Wais'
#  'Christian Hafenecker' 'Manfred Hofinger' 'Gerhard Schmid'
#  'Philipp Schrangl' 'Elisabeth Pfurtscheller' 'Andreas Ottenschläger'
#  'Walter Rauch' 'Peter Wurm' 'Marianne Gusenbauer-Jäger' 'Johannes Rauch'
#  'Friedrich Ofenauer' 'Uwe Feichtinger' 'Walter Bacher' 'Wendelin Mölzer'
#  'Angela Fichtinger' 'Andreas Hanger' 'Sebastian Kurz' 'Jessi Lintl'
#  'Markus Vogl' 'Daniela Holzinger-Vogtenhuber' 'Nurten Yilmaz'
#  'Harald Troch' 'Konrad Antoni' 'Sophie Karmasin' 'Josef Ostermayer'
#  'Josef Schellhorn' 'Thomas Schellenbacher' 'Erwin Angerer'
#  'Carmen Schimanek' 'Günther Kumpitsch' 'Jürgen Schabhüttl'
#  'Claudia Gamon' 'Hermann Brückl' 'Peter Doskozil' 'Wolfgang Sobotka'
#  'Christian Kern' 'Sonja Hammerschmid' 'Jörg Leichtfried'
#  'Wolfgang Klinger' 'Michael Bernhard' 'David Lasar' 'Thomas Drozda'
#  'Pamela Rendi-Wagner' 'Karin Doppelbauer' 'Harald Mahrer'
#  'Barbara Neuroth' 'Peter Kolba' 'Irmgard Griss' 'Stephanie Cox'
#  'Elisabeth Köstinger' 'Alma Zadic' 'Efgani Dönmez' 'Alfred J. Noll'
#  'Karl Nehammer' 'Martha Bißmann' 'Marlene Svazek' 'Johanna Jachs'
#  'Gabriela Schwarz' 'Johann Gudenus' 'Barbara Krenn'
#  'Carmen Jeitler-Cincelli' 'Karl Mahrer' 'Stefan Schnöll'
#  'Rudolf Taschner' 'Theresia Niss' 'Claudia Plakolm' 'Maria Großbauer'
#  'Ernst Gödl' 'Klaus Fürlinger' 'Beate Hartinger-Klein' 'Tanja Graf'
#  'Gernot Blümel' 'Martin Engelberg' 'Heinz Faßmann'
#  'Angelika Kuss-Bergner' 'Alois Rosenberger' 'Stephanie Krisper'
#  'Maria Holzleitner' 'Elisabeth Feichtinger' 'Maurice Androsch'
#  'Andreas Kollross' 'Sabine Schatz' 'Robert Laimer' 'Petra Wimmer'
#  'Mario Lindner' 'Andreas Kühberger' 'Muna Duzdar' 'Christoph Zarits'
#  'Selma Yildirim' 'Doris Margreiter' 'Nico Marchetti' 'Martina Kaufmann'
#  'Angela Baumgartner' 'Reinhold Einwallner' 'Hartwig Löger'
#  'Christian Ragger' 'Markus Tschank' 'Susanne Fürst' 'Klaudia Friedl'
#  'Irene Hochstetter-Lackner' 'Douglas Hoyos-Trauttmansdorff'
#  'Christoph Stark' 'Klaus Lindinger' 'Petra Wagner' 'Sandra Wassermann'
#  'Melanie Erasim' 'Rebecca Kirchbaumer' 'Josef Smolle' 'Dominik Schrott'
#  'Christian Pewny' 'Gudrun Kugler' 'Hannes Amesbauer' 'Kira Grünberg'
#  'Christian Ries' 'Silvia Sandler' 'Maria Smodics-Neumann'
#  'Verena Nussbaum' 'Renate Gruber' 'Christian Schandor' 'Gerhard Kaniak'
#  'Peter Weidinger' 'Christian Kovacevic' 'Karin Kneissl'
#  'Margarete Schramböck' 'Alois Kainz' 'Peter Schmiedlechner'
#  'Peter Gerstner' 'Juliane Bogner-Strauß' 'Ricarda Berger' 'Josef Moser'
#  'Gertraud Salzmann' 'Volker Reifenberger' 'Michaela Schartel']

# %%
#check number of speakers, clean from Titles, other names by only taking the last two words of the name.
#cleaned_speaker_list= df['speaker'].unique()
#print(len(cleaned_speaker_list))
#print(len(speaker_list))

# %%
#visualise mp/speeches distribution

#df['speaker'].value_counts().plot(kind='bar')
#plt.show()
#looks horribe! not sure how to make better

# %%
mean_speech_length= df['terms'].mean()

print("Mean of speech length: {}".format(mean_speech_length))

print("Overall speech length:\n shortest 5 % :  {0} words, \n longest 5 % percent: {1} words,\n 1st quantile : {2} words,\n 3rd quantile: {3} words \n median : {4} words \n standard deviation : {5} words".format(df['terms'].quantile(0.05),df['terms'].quantile(0.95),df['terms'].quantile(0.25),
      df['terms'].quantile(0.75),df['terms'].median(),df['terms'].std()))

print("Overview on speech length:\n {}".format(df['terms'].describe()))
# Out:
# Mean of speech length: 304.7709054997719
# Overall speech length:
#  shortest 5 % :  7.0 words,
#  longest 5 % percent: 1169.0 words,
#  1st quantile : 13.0 words,
#  3rd quantile: 471.0 words
#  median : 66.0 words
#  standard deviation : 528.4587415872023 words
# Overview on speech length:
#  count    199481.000000
# mean        304.770905
# std         528.458742
# min           1.000000
# 25%          13.000000
# 50%          66.000000
# 75%         471.000000
# max       62490.000000
# Name: terms, dtype: float64

# %%
filtered_speechlength= [i for i in df['terms'] if i > 46]
long_speeches=[i for i in df['terms'] if i > 2000]
speeches_over_BERtlength= [i for i in df['terms'] if i > 512]
print("Amount of speeches")
print("total: {}".format(len(df['terms'])))
print(">2000 words: {}".format(len(long_speeches)))
print(">13 words: {}".format(len(filtered_speechlength)))
print(">521 words:{}".format(len(speeches_over_BERtlength)))

print("Amount of words")     
print("Total: {}".format(sum(df['terms'])))
print("Without shortest 5% of speeches: {}".format(sum(filtered_speechlength)))
# Out:
# Amount of speeches
# total: 89774
# >2000 words: 1725
# >13 words: 85157
# >521 words:42330
# Amount of words
# Total: 52094997.0
# Without shortest 5% of speeches: 51959203.0

# %%
#show speech length boxplot
data= [df['terms'].std(),df['terms'].median(),df['terms'].quantile(0.75),df['terms'].quantile(0.25)]
fig1, ax1 = plt.subplots()
ax1.set_title('speechlength overall')
ax1.boxplot(data)
plt.show()

# %%
groups = df.groupby('party')['terms']

# sort by median (change this if you want a different metric)
groups_sorted = sorted(groups, key=lambda x: np.median(x[1].values))

data = [[
    group.values.std(),
    np.median(group.values),
    np.quantile(group.values, 0.75),
    np.quantile(group.values, 0.25)
] for name, group in groups_sorted]

labels = [name for name, group in groups_sorted]

fig, ax = plt.subplots()
ax.set_title('Speech length by party')
ax.boxplot(data, tick_labels=labels)

ax.set_xlabel('Party')
ax.set_ylabel('Terms')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
median = [np.median(group.values) for name, group in groups_sorted]

# %%
print(median, labels, data)
# Out:
# [14.0, 308.0, 418.0, 428.0, 543.0, 544.0, 553.0, 591.0, 617.0, 650.0, 687.5] [NA_character_, 'independent', 'ÖVP', 'SPÖ', 'FPÖ', 'BZÖ', 'PILZ', 'STRONACH', 'NEOS', 'Grüne', 'LIF'] [[420.11347121784274, 14.0, 35.0, 9.0], [654.5617914732815, 308.0, 709.5, 140.0], [480.69539078602054, 418.0, 680.0, 199.0], [455.04244526091827, 428.0, 696.5, 227.0], [547.1031540439776, 543.0, 836.0, 224.0], [494.0257016761162, 544.0, 881.0, 250.0], [485.98829781585584, 553.0, 806.75, 239.25], [432.8607468637475, 591.0, 840.75, 342.5], [423.43940909590714, 617.0, 839.75, 372.5], [568.3801727010749, 650.0, 976.0, 255.0], [761.4500385715412, 687.5, 1206.75, 183.0]]

# %% [markdown]
# #### thoughts and questions:
#
# * Are 89774 speeches enough material?
# * Is the distribution ok?
# * Is the lenght ok?
# * Should I ignore the 5% shortest speeches (<46 words)
# * would just progress with this as it is now

# %%
speeches_pivot=pd.pivot_table(df,values=['text'],index=['party','speaker'],aggfunc=['sum','count'])

# %%
speeches_pivot.to_excel('data/pivot_table_speeches.xlsx')

# %%
print("Overall distribution of speeches:\n fewest 5 % :  {0} speeches, \n most common 5 % percent: {1} speeches,\n 1st quantile : {2} speeches,\n 3rd quantile: {3} speeches \n median : {4} speeches \n standard deviation : {5} speeches \n mean : {6}".format(speeches_pivot['count'].quantile(0.05),speeches_pivot['count'].quantile(0.95),speeches_pivot['count'].quantile(0.25),
      speeches_pivot['count'].quantile(0.75),speeches_pivot['count'].median(),speeches_pivot['count'].std(),speeches_pivot['count'].mean()))
# Out:
# Overall distribution of speeches:
#  fewest 5 % :  text    3.0
# Name: 0.05, dtype: float64 speeches,
#  most common 5 % percent: text    320.0
# Name: 0.95, dtype: float64 speeches,
#  1st quantile : text    21.0
# Name: 0.25, dtype: float64 speeches,
#  3rd quantile: text    139.0
# Name: 0.75, dtype: float64 speeches
#  median : text    64.0
# dtype: float64 speeches
#  standard deviation : text    115.892125
# dtype: float64 speeches
#  mean : text    99.971047
# dtype: float64

# %% [markdown]
# #### More questions:
#
# Some MPs only have 5 speeches, others 1309, what would that do to training? <p/>
# Should each speech be a single training sample? For BERT that would be more usefull then concatinating it?

# %%
df= df.drop(columns=['count_president','count_scribe','count_minister','chair','parliament','iso3country','party.facts.id','speaker_old'])

# %%
#save everything as pickle for now: 
#df.to_pickle('data/dataset.pkl')
#speeches_pivot.to_pickle('data/pivot.pkl')
