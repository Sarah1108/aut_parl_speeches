# %% [markdown]
# ## Visualisations in my thesis
#
# In this notebook I am gathering all code used to create the visualisations in my thesis.
# The file used in this tutorial is avaliable as an Excel on my Github too.
# Some of these code snippes are found in other parts of my code in this repository too.

# %% [markdown]
# ### Chapter 3 Data

# %%
# import libraries 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pywaffle import Waffle
#import poli_sci_kit
import pltviz
import seaborn as sns
from poli_sci_kit import appointment
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
import regex as re

# %%
# read final data set
filename = "data/processed_results.xlsx"
df = pd.read_excel(filename, index_col=0)

# %%
# define colours and party dictionary
party_colour_dict_name= {
    'SPÖ':'#ff0000',
    'ÖVP':'#000000',
    'FPÖ':'#0066ff',
    'Grüne':'#92d050',
    'LIF':'#ffff40',
    'BZÖ':'#ee7f00',
    'NEOS':'#e84188',
    'STRONACH':'#fecd00',
    'PILZ':'#efebdc'
}
party_colour_dict= {
    0:'#ff0000',
    1:'#000000',
    2:'#0066ff',
    3:'#92d050',
    4:'#ffff40',
    5:'#ee7f00',
    6:'#e84188',
    7:'#fecd00',
    8:'#efebdc'
}

party_dict_name= {
    0:'SPÖ',
    1:'ÖVP',
    2:'FPÖ',
    3:'Grüne',
    4:'LIF',
    5:'BZÖ',
    6:'NEOS',
    7:'STRONACH',
    8:'PILZ'
}

# %%
# Figure 3.1.

readRDS = robjects.r['readRDS']
df = readRDS('data\Corp_Nationalrat_V2.rds')
df = pandas2ri.rpy2py_dataframe(df)
df['party']= df['party'].replace(to_replace='Jetzt – Liste PILZ', value='PILZ', regex=True)
df['party']= df['party'].replace(to_replace='JETZT', value='PILZ', regex=True)

all_party_colours= ['#a9a9a9','#ff0000','#000000','#0066ff','#92d050','#ee7f00','#fecd00','#e84188','#a9a9a9','#ffff40','#efebdc']
df['party'].value_counts().plot(kind='bar',color=all_party_colours)
plt.title('Overall distribution of speeches in  ParlV2 data set')
print(df['party'].value_counts())
plt.show()
# Out:
# NA_character_    109707
# SPÖ               24747
# ÖVP               24063
# FPÖ               17308
# Grüne             12455
# BZÖ                4170
# LIF                1942
# NEOS               1866
# independent        1555
# STRONACH           1322
# PILZ                346
# Name: party, dtype: int64

# %%
# Figure 3.2.
readRDS = robjects.r['readRDS']
df = readRDS('data\Corp_Nationalrat_V2.rds')
df = pandas2ri.rpy2py_dataframe(df)
df['party']= df['party'].replace(to_replace='Jetzt – Liste PILZ', value='PILZ', regex=True)
df['party']= df['party'].replace(to_replace='JETZT', value='PILZ', regex=True)

all_party_colours= ['#a9a9a9','#ff0000','#000000','#0066ff','#92d050','#ee7f00','#fecd00','#e84188','#a9a9a9','#ffff40','#efebdc']
df['party'].value_counts().plot(kind='bar',color=all_party_colours)
plt.title('Overall distribution of speeches in  ParlV2 data set')
print(df['party'].value_counts())
plt.show()
# Out:
# SPÖ            24747
# ÖVP            24063
# FPÖ            17308
# Grüne          12455
# BZÖ             4170
# LIF             1942
# NEOS            1866
# independent     1555
# STRONACH        1322
# PILZ             346
# Name: party, dtype: int64

# %%
# Figure 3.3.
#filter out speeches by president of parliament and scribes
search = "präsident"
df['count_president']= df["speaker"].str.count(search, re.I)

search_2 = "bundesminister"
df['count_minister']= df["speaker"].str.count(search_2, re.I)


search_3 = "schriftführer"
df['count_scribe'] = df["speaker"].str.count(search_3, re.I)


df = df[df['count_president']<1]
df = df[df['count_scribe']<1]

all_party_colours= ['#ff0000','#000000','#0066ff','#92d050','#ee7f00','#fecd00','#e84188','#a9a9a9','#ffff40','#efebdc']
df['party'].value_counts().plot(kind='bar',color=all_party_colors)
print(df['party'].value_counts())
plt.show()

# %%
# Figure 3.4.

data= [df['terms'].std(),df['terms'].median(),df['terms'].quantile(0.75),df['terms'].quantile(0.25)]
fig1, ax1 = plt.subplots()
ax1.set_title('speechlength overall')
ax1.boxplot(data)
plt.show()

# %%
# Figure 3.5.
# Figure 3.4.

groups = df.groupby('party')['terms']

# sort by median (change this if you want a different metric)
groups_sorted = sorted(groups, key=lambda x: np.median(x[1].values))

data = [[
    group.values.std(),
    np.median(group.values),
    np.quantile(group.values, 0.75),
    np.quantile(group.values, 0.25)
] for name, group in groups_sorted]

labels = [name for name, group in groups_sorted]

fig, ax = plt.subplots()
ax.set_title('Speech length by party')
ax.boxplot(data, tick_labels=labels)

ax.set_xlabel('Party')
ax.set_ylabel('Terms')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Figure 3.6.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       1 # Figure 3.6.
#       2
#       3 #visualise parties/speech distribution
# ----> 4 df['party'].value_counts().plot(kind='bar',color=all_party_colors)
#       5 #print(df['party'].value_counts())
#       6 plt.show()
#
# NameError: name 'all_party_colors' is not defined

# %%
# Figure 3.7.

# %%
# Figure 3.8.

# %%
# Figure 3.9

# %%
# Figure 3.10 to 3.16

# %%
# Figure 3.17

# %% [markdown]
# ### Chapter 4 Data preprocessing and training

# %%
# Figure 4.1

# %% [markdown]
# ### Chapter 5 Evaluation and Results

# %%
mp_prob = pd.read_excel("data/tsnefinal.xlsx")
mp_prob
# Out:
#                 speaker  text         0         1         2         3  \
# 0    Albert Steinhauser   350  2.386625 -0.396127  0.223168  2.606408
# 1            Alev Korun   222  2.565539 -0.060719  0.125154  2.785238
# 2         Alfred Brader    62  2.704904  5.512569  2.093183 -2.316503
# 3     Alfred Gusenbauer   343  5.441470  2.375222  0.704255 -0.561125
# 4        Alfred J. Noll    52  1.271763  0.202550  1.528535  1.704534
# ..                  ...   ...       ...       ...       ...       ...
# 637    Wolfgang Spadiut   120  1.041129  0.655568  3.843277 -1.349485
# 638     Wolfgang Zanger   177  0.726944  0.466823  4.861429 -0.811060
# 639     Wolfgang Zinggl   270  1.846195 -0.528018  1.022103  2.063666
# 640          Xaver Böhm    35  1.666997  5.186667  3.815378 -2.843272
# 641          der Bellen   515  1.916047 -0.075554  1.016818  4.248480
#
#             4         5         6         7         8  party  predicted_party  \
# 0   -2.089251 -0.114238 -0.566620 -2.065270 -1.139825      3                3
# 1   -1.939723 -1.391903 -0.309045 -2.068509 -0.208931      3                3
# 2   -2.695349  0.135026 -3.373236 -2.660042 -3.664521      1                1
# 3   -1.001213 -1.716029 -2.896559 -2.827513 -2.150333      0                0
# 4   -2.538633 -1.351130  0.136536 -1.756680 -0.958200      8                3
# ..        ...       ...       ...       ...       ...    ...              ...
# 637 -2.581426  1.733207 -2.402049 -0.539682 -2.845607      5                2
# 638 -2.637704  1.559566 -1.771170 -0.781567 -2.759154      2                2
# 639 -2.451775 -0.538586 -0.687140 -1.016371 -0.574390      3                3
# 640 -2.736056  0.761780 -2.652491 -1.770449 -3.849705      1                1
# 641 -0.584291 -1.264747 -2.553333 -2.661349 -2.140572      3                3
#
#              x          y
# 0   -18.385195  16.458616
# 1   -18.198277  17.533043
# 2     9.922507 -15.910868
# 3   -21.976698  -4.093795
# 4   -15.263634  16.730171
# ..         ...        ...
# 637  32.292168  11.897616
# 638  29.759056  14.969832
# 639 -17.078453  16.235596
# 640  17.634373  -5.444448
# 641 -23.042154  17.519442
#
# [642 rows x 15 columns]

# %%
x = mp_prob['x']
y = mp_prob['y']

colors_map={0:'#ff0000',1:'#000000',2:'#0066ff',3:'#92d050',5:'#ee7f00',4:'#fecd00',6:'#e84188',8:'#a9a9a9',7:'#ffff40',9:'#efebdc'}
colors= [colors_map[color] for color in mp_prob['party']]

fig, ax = plt.subplots()

labels = ['SPÖ(center-left)','ÖVP(center-right)','FPÖ(far right)','GRÜNE(left)','BZÖ(right)','LIF(center-liberal)','NEOS(center-liberal)','STRONACH(right)','PILZ(left)']
party_ids = [0,1,2,3,5,4,6,7,8]   # same order as labels

for pid, label in zip(party_ids, labels):
    mask = mp_prob['party'] == pid
    ax.scatter(mp_prob.loc[mask, 'x'],
               mp_prob.loc[mask, 'y'],
               c=colors_map[pid],
               label=label,
               linewidth=0)

ax.legend(loc='right',bbox_to_anchor=(1.45, 0.5))
plt.title('CMs with at least 11 speeches',fontsize=16)
plt.show()

# %% [markdown]
# ### Chapter 6 Political Developements

# %%
# Figure 6.1 and 6.2

# %%
# Figure 6.3

# %%
# Figure 6.4 and 6.5

# %%
# Figure 6.6 to 6.10

# %%
# Figure 6.11 to 6.22

# %%
# Figure 6.23 to 6.27
